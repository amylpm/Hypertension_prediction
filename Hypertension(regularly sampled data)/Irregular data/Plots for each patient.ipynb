# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from datetime import date, datetime
sns.set(font_scale=2)
pd.set_option('display.max_rows', None)

# %%
bp= pd.read_excel(r'./../data/20220426/bp_20220426.xlsx')

# %%
bp.describe()
# Out:
#           patientID      systolic    diastolic        pulse
# count   4070.000000   4070.000000  4070.000000  4070.000000
# mean   14440.375676    132.770762    77.735135    74.554791
# std      149.128058    199.639537    13.189737    22.963996
# min    14042.000000     59.000000     0.000000     0.000000
# 25%    14432.000000    119.000000    69.000000    65.000000
# 50%    14487.000000    129.000000    79.000000    73.000000
# 75%    14536.000000    138.000000    86.000000    83.000000
# max    14614.000000  12822.000000   131.000000   779.000000

# %%
count = pd.DataFrame(bp.patientID.value_counts())
count[count['patientID']>1]
#or 
#bp['patientID'].value_counts().loc[lambda x : x>50]
# Out:
#        patientID
# 14042        431
# 14487        301
# 14536        259
# 14593        253
# 14432        249
# 14549        191
# 14442        148
# 14506        130
# 14488        114
# 14582        110
# 14448        106
# 14341         93
# 14562         92
# 14443         92
# 14475         88
# 14500         75
# 14386         74
# 14512         66
# 14461         56
# 14498         53
# 14403         51
# 14414         50
# 14388         50
# 14521         49
# 14520         46
# 14444         44
# 14385         40
# 14523         38
# 14445         37
# 14483         37
# 14537         37
# 14454         36
# 14451         36
# 14395         32
# 14542         28
# 14481         26
# 14514         25
# 14426         22
# 14391         21
# 14474         19
# 14435         19
# 14526         18
# 14538         18
# 14557         18
# 14425         17
# 14515         16
# 14516         16
# 14413         15
# 14499         15
# 14404         15
# 14589         14
# ...

# %%
plt.figure(figsize=(50, 20))
plt.xticks(rotation=90)
sns.countplot(x ='patientID', data = bp, order = bp['patientID'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='patientID', ylabel='count'>

# %%
#for all value
#bp.patientID.value_counts()

# %%
for i, (ID, subdf) in enumerate(bp.groupby('patientID'), 1):
    locals()[f'bp{ID}'] = subdf

# %%
bp14042
# Out:
#       patientID  systolic  diastolic  pulse          recordTime  \
# 0         14487       142         77     69 2022-04-26 16:45:00
# 2         14487       138         77     55 2022-04-26 05:40:00
# 4         14487       133         81     84 2022-04-25 17:05:00
# 8         14487       128         82     66 2022-04-25 06:00:00
# 10        14487       130         76     64 2022-04-24 16:45:00
# 12        14487       141         84     60 2022-04-24 06:40:00
# 17        14487       126         73     90 2022-04-23 16:13:00
# 19        14487       139         78     61 2022-04-23 06:30:00
# 21        14487       131         77     63 2022-04-22 16:30:00
# 23        14487       138         76     53 2022-04-22 06:20:00
# 26        14487       138         77     66 2022-04-21 16:30:00
# 28        14487       135         83     57 2022-04-21 06:00:00
# 29        14487       135         72     76 2022-04-20 16:35:00
# 30        14487       143         80     54 2022-04-20 07:30:00
# ...

# %%
plt.figure(figsize=(20, 10))
plt.plot(bp14042['recordTime'],bp14042['systolic'],linestyle='--', marker='o', label = "Systolic")#title = index)
plt.plot(bp14042['recordTime'],bp14042['diastolic'],linestyle='--', marker='*', label = "Diastolic")
plt.plot(bp14042['recordTime'],bp14042['pulse'],linestyle='--', marker='x',label = "Pulse")
plt.legend(bbox_to_anchor=(1.1, 1.05))
plt.xticks(rotation=90)
plt.title('No.1 :patient_14042')
plt.axhline(y = 50, color='r',linestyle='-.', linewidth = 0.5)
plt.axhline(y = 250, color='r',linestyle='-.', linewidth = 0.5)
plt.show()

# %%
plt.figure(figsize=(20, 10))
plt.plot(bp14487['recordTime'],bp14487['systolic'],linestyle='--', marker='o', label = "Systolic")#title = index)
plt.plot(bp14487['recordTime'],bp14487['diastolic'],linestyle='--', marker='*', label = "Diastolic")
plt.plot(bp14487['recordTime'],bp14487['pulse'],linestyle='--', marker='x',label = "Pulse")
plt.legend(bbox_to_anchor=(1.1, 1.05))
plt.xticks(rotation=90)
plt.title('No.2: patient_14487')
plt.axhline(y = 50, color='r',linestyle='-.', linewidth = 0.5)
plt.axhline(y = 250, color='r',linestyle='-.', linewidth = 0.5)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(bp14536['recordTime'],bp14536['systolic'],linestyle='--', marker='o', label = "Systolic")#title = index)
plt.plot(bp14536['recordTime'],bp14536['diastolic'],linestyle='--', marker='*', label = "Diastolic")
plt.plot(bp14536['recordTime'],bp14536['pulse'],linestyle='--', marker='x',label = "Pulse")
plt.legend(bbox_to_anchor=(1.1, 1.05))
plt.xticks(rotation=90)
plt.title('No.3: patient_14356')
plt.axhline(y = 50, color='r',linestyle='-.', linewidth = 0.5)
plt.axhline(y = 250, color='r',linestyle='-.', linewidth = 0.5)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(bp14593['recordTime'],bp14593['systolic'],linestyle='--', marker='o', label = "Systolic")#title = index)
plt.plot(bp14593['recordTime'],bp14593['diastolic'],linestyle='--', marker='*', label = "Diastolic")
plt.plot(bp14593['recordTime'],bp14593['pulse'],linestyle='--', marker='x',label = "Pulse")
plt.legend(bbox_to_anchor=(1.1, 1.05))
plt.xticks(rotation=90)
plt.title('No. 4: patient_14593')
plt.axhline(y = 50, color='r',linestyle='-.', linewidth = 0.5)
plt.axhline(y = 250, color='r',linestyle='-.', linewidth = 0.5)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(bp14432['recordTime'],bp14432['systolic'],linestyle='--', marker='o', label = "Systolic")#title = index)
plt.plot(bp14432['recordTime'],bp14432['diastolic'],linestyle='--', marker='*', label = "Diastolic")
plt.plot(bp14432['recordTime'],bp14432['pulse'],linestyle='--', marker='x',label = "Pulse")
plt.legend(bbox_to_anchor=(1.1, 1.05))
plt.xticks(rotation=90)
plt.title('No.5 :patient_14432')
plt.axhline(y = 50, color='r',linestyle='-.', linewidth = 0.5)
plt.axhline(y = 250, color='r',linestyle='-.', linewidth = 0.5)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(bp14549['recordTime'],bp14549['systolic'],linestyle='--', marker='o', label = "Systolic")#title = index)
plt.plot(bp14549['recordTime'],bp14549['diastolic'],linestyle='--', marker='*', label = "Diastolic")
plt.plot(bp14549['recordTime'],bp14549['pulse'],linestyle='--', marker='x',label = "Pulse")
plt.legend(bbox_to_anchor=(1.1, 1.05))
plt.xticks(rotation=90)
plt.title('No. 6:patient_14549')
plt.axhline(y = 50, color='r',linestyle='-.', linewidth = 0.5)
plt.axhline(y = 250, color='r',linestyle='-.', linewidth = 0.5)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(bp14442['recordTime'],bp14442['systolic'],linestyle='--', marker='o', label = "Systolic")#title = index)
plt.plot(bp14442['recordTime'],bp14442['diastolic'],linestyle='--', marker='*', label = "Diastolic")
plt.plot(bp14442['recordTime'],bp14442['pulse'],linestyle='--', marker='x',label = "Pulse")
plt.legend(bbox_to_anchor=(1.1, 1.05))
plt.xticks(rotation=90)
plt.title('No 7: patient_14442')
plt.axhline(y = 50, color='r',linestyle='-.', linewidth = 0.5)
plt.axhline(y = 250, color='r',linestyle='-.', linewidth = 0.5)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(bp14506['recordTime'],bp14506['systolic'],linestyle='--', marker='o', label = "Systolic")#title = index)
plt.plot(bp14506['recordTime'],bp14506['diastolic'],linestyle='--', marker='*', label = "Diastolic")
plt.plot(bp14506['recordTime'],bp14506['pulse'],linestyle='--', marker='x',label = "Pulse")
plt.legend(bbox_to_anchor=(1.1, 1.05))
plt.xticks(rotation=90)
plt.title('No. 7: patient_14506')
plt.axhline(y = 50, color='r',linestyle='-.', linewidth = 0.5)
plt.axhline(y = 250, color='r',linestyle='-.', linewidth = 0.5)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(bp14488['recordTime'],bp14488['systolic'],linestyle='--', marker='o', label = "Systolic")#title = index)
plt.plot(bp14488['recordTime'],bp14488['diastolic'],linestyle='--', marker='*', label = "Diastolic")
plt.plot(bp14488['recordTime'],bp14488['pulse'],linestyle='--', marker='x',label = "Pulse")
plt.legend(bbox_to_anchor=(1.1, 1.05))
plt.xticks(rotation=90)
plt.title('No.8 :patient_14488')
plt.axhline(y = 50, color='r',linestyle='-.', linewidth = 0.5)
plt.axhline(y = 250, color='r',linestyle='-.', linewidth = 0.5)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(bp14582['recordTime'],bp14582['systolic'],linestyle='--', marker='o', label = "Systolic")#title = index)
plt.plot(bp14582['recordTime'],bp14582['diastolic'],linestyle='--', marker='*', label = "Diastolic")
plt.plot(bp14582['recordTime'],bp14582['pulse'],linestyle='--', marker='x',label = "Pulse")
plt.legend(bbox_to_anchor=(1.1, 1.05))
plt.xticks(rotation=90)
plt.title('No. 9:patient_14582')
plt.axhline(y = 50, color='r',linestyle='-.', linewidth = 0.5)
plt.axhline(y = 250, color='r',linestyle='-.', linewidth = 0.5)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(bp14448['recordTime'],bp14448['systolic'],linestyle='--', marker='o', label = "Systolic")#title = index)
plt.plot(bp14448['recordTime'],bp14448['diastolic'],linestyle='--', marker='*', label = "Diastolic")
plt.plot(bp14448['recordTime'],bp14448['pulse'],linestyle='--', marker='x',label = "Pulse")
plt.legend(bbox_to_anchor=(1.1, 1.05))
plt.xticks(rotation=90)
plt.title('No 10: patient_14448')
plt.axhline(y = 50, color='r',linestyle='-.', linewidth = 0.5)
plt.axhline(y = 250, color='r',linestyle='-.', linewidth = 0.5)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(bp14475['recordTime'],bp14475['systolic'],linestyle='--', marker='o', label = "Systolic")#title = index)
plt.plot(bp14475['recordTime'],bp14475['diastolic'],linestyle='--', marker='*', label = "Diastolic")
plt.plot(bp14475['recordTime'],bp14475['pulse'],linestyle='--', marker='x',label = "Pulse")
plt.legend(bbox_to_anchor=(1.1, 1.05))
plt.xticks(rotation=90)
plt.title('patient_14475')
plt.axhline(y = 50, color='r',linestyle='-.', linewidth = 0.5)
plt.axhline(y = 250, color='r',linestyle='-.', linewidth = 0.5)
plt.show()
